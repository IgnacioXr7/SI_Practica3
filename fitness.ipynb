# %% [markdown]
# Lista de columnas clave:
#
# -bmi
# -fitness_level
# -age
# -activate_minutes
# -steps_per_day
# -sleep_hours
# -sleep_quality
# -diet_quality
# -hydration_liters

# %%
import pandas as pd
import numpy as np


df = pd.read_csv('fitness_dataset.csv')

df = df.drop(columns=['lifestyle_category', 'workouts_per_week', 'heart_rate_resting',  'consistency_score', 'calories_burned'])

print(f"Dataset original: {df}")
# Out:
# Dataset original:         age  steps_per_day  active_minutes  sedentary_minutes  sleep_hours  \
# 0        56          12633             122               1084         8.65
# 1        46           1980              33               1122         5.97
# 2        32           7139              60               1049         6.23
# 3        60           4814              66               1018         5.09
# 4        25           8096              86               1031         5.49
# ...     ...            ...             ...                ...          ...
# 999995   32           2742              39               1087         5.70
# 999996   64           4253              35               1175         7.03
# 999997   52           6425              79               1125         5.39
# 999998   48           3871              39                998         8.34
# 999999   37           9226             106               1040         8.81
#
#         sleep_quality  stress_level  workouts_per_week  diet_quality  \
# 0                8.67          4.42                  2          5.61
# 1                5.37          7.91                  2          8.17
# 2                7.15          4.20                  0          3.47
# 3                7.61          7.12                  4          5.26
# 4                5.57          3.88                  3          2.60
# ...               ...           ...                ...           ...
# 999995           6.59          4.44                  3          7.05
# 999996           6.26          5.79                  3          4.15
# 999997           7.40          5.39                  6          7.44
# 999998           8.29          5.21                  7          8.71
# 999999           9.31          4.40                  5          9.27
#
#         hydration_liters    bmi  heart_rate_avg fitness_level
# 0                   2.14  16.00           103.0      Moderate
# 1                   0.92  37.07           126.3         Unfit
# 2                   2.67  27.36           101.4         Unfit
# 3                   2.17  24.59           107.8      Moderate
# 4                   2.91  19.07            92.8      Moderate
# ...                  ...    ...             ...           ...
# 999995              2.52  31.34           150.4         Unfit
# 999996              2.82  29.62           106.2         Unfit
# 999997              3.69  21.53           118.0      Moderate
# 999998              2.15  33.33           105.1      Moderate
# 999999              0.87  16.90            86.7           Fit
#
# [1000000 rows x 13 columns]

# %% [markdown]
# Lista de pasos:
#
# -eliminacion/limpieza de tabla
# -division de salidas equitativa
# -eliminacion de campos nulos
# -Seleccion de un modelo especifico(redes neuronales, KNM, Arbol de decision, SVM)
# -
